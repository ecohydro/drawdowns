# %% [markdown]
# # Drawdown
#
# Find the locations, magnitude, and duration of drawdown events in a time series of Plant Available Water Storage.

# %%
from Drawdown import Drawdown, cum_dist
file = 'CalhounS.csv'
drawdown = Drawdown(filename=file, find_drawdowns=True, debug=False)
# Out:
# [2023-03-07 11:54:28,742 Drawdown.py->__init__():65]INFO: There are 4656 total downvals
# [2023-03-07 11:54:28,743 Drawdown.py->__init__():66]INFO: There are 4656 total upvals
# [2023-03-07 11:54:28,743 Drawdown.py->__init__():68]INFO: Cacluating drawdowns...
#   0%|          | 0/4655 [00:00<?, ?it/s]

# %% [markdown]
# ## Drawdown Plot

# %%
drawdown.plot(
    threshold=470,
    show_up_locs=False,show_down_locs=False,
    offset=20)

# %% [markdown]
# ## Drawdown Distribution

# %%
from matplotlib import pyplot as plot
x, y = cum_dist(drawdown.df['magnitude'])
plot.plot(x,y)
plot.xlabel('Drawdown Size, d (cm)')
plot.ylabel('Cumulative Distribution, F(d)')
plot.title('CDF of Drawdown Sizes, F(d)')
# Out:
# Text(0.5, 1.0, 'CDF of Drawdown Sizes, F(d)')

# %% [markdown]
# ## Drawdown Stats

# %%
drawdown.df[['magnitude','duration','filling','draining']].describe()
# Out:
#          magnitude      duration      filling     draining
# count  4655.000000   4655.000000  4655.000000  4655.000000
# mean      8.894710     17.069388   134.279650    74.141744
# std      45.307107    234.462250   319.765061   169.260891
# min       0.001167      2.000000     0.001167     0.070000
# 25%       0.640000      2.000000     1.220000     1.875914
# 50%       1.849125      2.000000     8.170000     5.932534
# 75%       5.390000      6.000000   111.557844    40.051504
# max    1337.616437  13964.000000  2531.870806  1337.616437

# %%
import numpy as np
drawdown.df['magnitude'].sum()
# Out:
# 41404.875347000096

# %%
drawdown.S[-10:]
# Out:
# array([7189.145914, 7190.220914, 7190.045325, 7190.048325, 7189.867957,
#        7189.867957, 7189.660968, 7189.660968, 7189.442964, 7189.442964])

# %%
26647.650241000000 -  26647.650240999938
# Out:
# 6.184563972055912e-11

# %%
a = 0.000417

# %%
a
# Out:
# 0.000417

# %%
a + 0.000001 - 0.000001
# Out:
# 0.000417

# %%
np.sum(np.sort(drawdown.df['magnitude']))
# Out:
# 26647.650240999934
